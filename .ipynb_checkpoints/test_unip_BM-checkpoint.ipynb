# %%
# %load_ext autoreload
# %autoreload 2
from combunipotent import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
part, rtype = (2,2,2,2,2,2,1,1), 'M'
part, rtype = (2,2,2,2), 'M'

part2drc(part,rtype=rtype,print_Wrepn=True,printdig=False)
gg = gen_lift_graph(part,rtype,format='pdf')
gg.render()
display(gg)
# Out:
# Type M partition: (2, 2, 2, 2)
# List of relevent Weyl group representations
# [([1, 1], [1, 1])]
# Number of drc diagrams: 9
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">3</span>,<span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">3</span>,      #ALS    <span style="color: #000080; font-weight: bold">12</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">6</span>,      #GLS    <span style="color: #000080; font-weight: bold">12</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type M  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">5</span>,      #ALS    <span style="color: #000080; font-weight: bold">5</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">5</span>,      #GLS    <span style="color: #000080; font-weight: bold">5</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">the ndrc and LS has no lift
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">c|r ====&gt; c|rd
#            |a
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">-+ =====&gt;
# *=
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">a local system packet has different epsilon
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">c|r , <span style="color: #000080; font-weight: bold">1</span> ,  -+  ---&gt;  c|sr  ,  +-+
#            *=         |a      -+-
#                               +
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">c|d , <span style="color: #000080; font-weight: bold">0</span> ,  *= | =*  ---&gt;  c|dd  ,  +-+
#            *= | *=         |a      -+-
#                                    +
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">7</span>,      #ALS    <span style="color: #000080; font-weight: bold">28</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">13</span>,     #GLS    <span style="color: #000080; font-weight: bold">23</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Missing <span style="color: #000080; font-weight: bold">6</span> LS:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">=*= | *=*
# =*= | =*=
# +   | -
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">~~~~~~~~~~~~~~~
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">+-+
# =*=
# *
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">~~~~~~~~~~~~~~~
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">+-+
# +-+
# *
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">~~~~~~~~~~~~~~~
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">-+- | +-+
# -+- | -+-
# *   | =
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">~~~~~~~~~~~~~~~
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">*=*
# *=*
# +
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">~~~~~~~~~~~~~~~
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">*=*
# -+-
# +
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">~~~~~~~~~~~~~~~
# </pre>

# %%
part, rtype = (3,3,1,1), 'M'
part2drc(part,rtype=rtype,print_Wrepn=True,printdig=True);

# %%
part = [7,7,6,6,5,5,4,4,3,3,2,2,1,1]
part = [7,7,5,5,3,3,1,1]
part = [13,13,11,11,7,7,2,2,1,1]
part = [9,9,5,5,3,3]
#part = [2,2,1,1]
rtype = 'M'
test_purelyeven(part,rtype=rtype);
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">3</span>,      #ALS    <span style="color: #000080; font-weight: bold">12</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">6</span>,      #GLS    <span style="color: #000080; font-weight: bold">12</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type M  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">12</span>,     #ALS    <span style="color: #000080; font-weight: bold">12</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">12</span>,     #GLS    <span style="color: #000080; font-weight: bold">12</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">24</span>,     #ALS    <span style="color: #000080; font-weight: bold">96</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">48</span>,     #GLS    <span style="color: #000080; font-weight: bold">96</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type M  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">96</span>,     #ALS    <span style="color: #000080; font-weight: bold">96</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">96</span>,     #GLS    <span style="color: #000080; font-weight: bold">96</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">9</span>, <span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">384</span>,    #ALS    <span style="color: #000080; font-weight: bold">1536</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">768</span>,    #GLS    <span style="color: #000080; font-weight: bold">1536</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type M  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">9</span>, <span style="color: #000080; font-weight: bold">9</span>, <span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">1536</span>,   #ALS    <span style="color: #000080; font-weight: bold">1536</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">1536</span>,   #GLS    <span style="color: #000080; font-weight: bold">1536</span>
# </pre>

# %%
part = [7,5,5,3,3]
#part = [5,4,4]
part = [5,3,3]
a = print_drc_diag_B(part,print_Wrepn=True)
b = part2drc(part,'B',print_Wrepn=True,printdig=False)
c = print_list_LS(part,'B')
#compare_drc(a,b)

# %%
part = (8,8,7,7,5,5,1,1)
rtype = 'M'
test_purelyeven(part,rtype=rtype);

# %%
part = [2,2,2,2,2,2,2,2,1,1]
rtype = 'M'
test_purelyeven(part,rtype=rtype);

# %%
## Example of strange annihlation of LS
test_LSDRC([8,3,3,1,1],'D',report=False,reportann=True)

# %%
test_LSDRC([4,3,3,2,2,1,1],'D',report=False, reportann=True)

# %%
partM = [3,3]
DRCLS1 = lift_drcs(dict(),rtype='B',ltype=partM[-1])
DRCLS2 = lift_drcs(DRCLS1, rtype='M', ltype='l')
print_list_LS(partM,'M')
print_DRCLS(DRCLS1, 'B')
print('DRCLS',len(DRCLS2))
print_DRCLS(DRCLS2,'M')

# %%
test_LSDRC([9,6,6,3,3,2,2,1,1],'B',report=False)

# %%
test_LSDRC([7,6,6,5,5,4,4,3,3,2,2,1,1],'B',report=False)

# %%
test_LSDRC([6,5,5,4,4,3,3,2,2,1,1],'D',report=False)

# %%
test_LSDRC([6,6,5,5,4,4,3,3,2,2,1,1],'M', report=False)

# %%
#part0, parta, rtype=(3,3,2,2,1,1), (3,3), 'C'
part0, parta, rtype=(1,1), (1,1), 'C'
part = parta*2+part0
part2drc(part0,rtype, printdig=True)
part2LS(part0,rtype, printdig=True)
#part, rtype=[1,1,1,1], 'C'
part2drc(part,rtype,printdig = True)
part2LS(part,rtype, printdig=True)

# %%
#part,rtype=(4,3,3,1,1), 'D'
part,rtype=(1,1,)*5,'C'
test_LSDRC(part,rtype,report=True,reportann=False)

# %%
#part,rtype=(4,3,3,1,1), 'D'
part,rtype=(5,5)*4+(3,3,)*5+(2,2),'C'
#part,rtype=(6,6,2,2,1,1),'C'
#part,rtype=(1,1,)*5,'C'
part,rtype=(7,7)*5+(2,2)+(1,1)*4,'C'
test_purelyeven(part,rtype,report=False,reportann=False)

# %%
#part,rtype=(4,3,3,1,1), 'D'
#part,rtype=(5,5)*4+(4,4)+(3,3,)*4+(2,2)+(1,1,)*4,'C'
part,rtype=(4,4)*5+(3,3)+(2,2,)*5,'M'
#part,rtype=(2,2,)*4,'M'
test_purelyeven(part,rtype,report=False,reportann=False)
0

# %%
#part,rtype=(4,3,3,1,1), 'D' 
#part,rtype=(5,5)*4+(4,4)+(3,3,)*4+(2,2)+(1,1,)*4,'C'
part,rtype=(3,3,)*5+(2,2),'C'
test_purelyeven(part,rtype,report=False,reportann=False,reportpack=False)

# %%
#part,rtype=(4,3,3,1,1), 'D'
#part,rtype=(5,5)*4+(4,4)+(3,3,)*4+(2,2)+(1,1,)*4,'C'
#part,rtype=(4,4)*5+(3,3)+(2,2,)*5,'M'
part,rtype=(4,2,2,),'D'
test_purelyeven(part,rtype,report=True,reportann=False)

# %%
#part,rtype=(4,3,3,1,1), 'D'
#part,rtype=(5,5)*4+(4,4)+(3,3,)*4+(2,2)+(1,1,)*4,'C'
part,rtype=(5,5)*5+(2,2)+(1,1,)*5,'C'
part,rtype=(4,2,2,1,1,1,1,),'D'
#part,rtype=(2,1,1,),'D'
part,rtype=(3,3,1,1,),'C'
test_purelyeven(part,rtype,report=False,reportann=False)

# %%
part,rtype=(3,1,1,),'D'
test_purelyeven(part,rtype,report=True,reportann=False)
0

# %%
''.join(range(0))

# %%
a = 'abc'
('',*a)
